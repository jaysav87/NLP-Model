# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
#get metadata for youtube videos from csv
v_df = pd.read_csv(r'youtube_links_with_metadata2.csv')

# %%
sn.scatterplot(data = v_df, x = "views", y = "Subscribers")
# Out:
# <AxesSubplot:xlabel='views', ylabel='Subscribers'>

# %%
sn.scatterplot(data = v_df, x = "views", y = "Likes")
# Out:
# <AxesSubplot:xlabel='views', ylabel='Likes'>

# %%
sn.scatterplot(data = v_df, x = "Subscribers", y = "Likes")
# Out:
# <AxesSubplot:xlabel='Subscribers', ylabel='Likes'>

# %%
v_df['Reach'] = v_df['views']/v_df['Subscribers']
v_df
# Out:
#     Unnamed: 0                                link  \
# 0            0        https://youtu.be/0JE-VbmzQzo
# 1            1        https://youtu.be/OQGLZxPcd-o
# 2            2        https://youtu.be/79aMfc-SxzE
# 3            3        https://youtu.be/auhfI1zWBco
# 4            4        https://youtu.be/gohJtZq54rU
# 5            5        https://youtu.be/JHo9RG0FXwQ
# 6            6        https://youtu.be/auhfI1zWBco
# 7            7        https://youtu.be/EWuz7GpeYqQ
# 8            8        https://youtu.be/N4uJIbPb8yU
# 9            9        https://youtu.be/lqd-A6bteqw
# 10          10        https://youtu.be/XN4GSRObmBA
# 11          11        https://youtu.be/n8bPLA6jtE0
# 12          12        https://youtu.be/1-O7zuaZsAA
# 13          13        https://youtu.be/R5Xa6eMAriQ
# 14          14        https://youtu.be/i411gIDzPb4
# 15          15        https://youtu.be/OvYuAT3J9no
# 16          16        https://youtu.be/tD4rVnD9mho
# ...

# %%
test = sn.scatterplot(data = v_df, x = "Reach", y = "views" )
test.set(xscale="log")
# Out:
# [None]

# %%
v_df['Rating'] = pd.qcut(v_df['Reach'], q=5)

# %%
#Let's do a little data preprocessing.

#datafull['Text'] = datafull['Text'].apply(lambda x :clean_doc(x))

#data = datafull[['Text','Genre of Movie']].copy()

v_df['Rating'] = v_df['Rating'].astype("category")
v_df['Rating'] = v_df['Rating'].cat.codes
#v_df['Genre of Movie code'].tail().T

# %%
v_df['key'] = v_df['link'].str.split('be/').str[-1]

# %%
v_df
# Out:
#     Unnamed: 0                                link  \
# 0            0        https://youtu.be/0JE-VbmzQzo
# 1            1        https://youtu.be/OQGLZxPcd-o
# 2            2        https://youtu.be/79aMfc-SxzE
# 3            3        https://youtu.be/auhfI1zWBco
# 4            4        https://youtu.be/gohJtZq54rU
# 5            5        https://youtu.be/JHo9RG0FXwQ
# 6            6        https://youtu.be/auhfI1zWBco
# 7            7        https://youtu.be/EWuz7GpeYqQ
# 8            8        https://youtu.be/N4uJIbPb8yU
# 9            9        https://youtu.be/lqd-A6bteqw
# 10          10        https://youtu.be/XN4GSRObmBA
# 11          11        https://youtu.be/n8bPLA6jtE0
# 12          12        https://youtu.be/1-O7zuaZsAA
# 13          13        https://youtu.be/R5Xa6eMAriQ
# 14          14        https://youtu.be/i411gIDzPb4
# 15          15        https://youtu.be/OvYuAT3J9no
# 16          16        https://youtu.be/tD4rVnD9mho
# ...

# %%
v_df['Rating'].value_counts()
# Out:
# 2    4
# 4    4
# 0    4
# 1    4
# 3    3
# Name: Rating, dtype: int64

# %%
triples1 = pd.read_csv(r'0JE-VbmzQzo-triples.csv')
triples1['key'] = '0JE-VbmzQzo'

triples2 = pd.read_csv(r'1-O7zuaZsAA-triples.csv')
triples2['key'] = '1-O7zuaZsAA'

triples3 = pd.read_csv(r'79aMfc-SxzE-triples.csv')
triples3['key'] = '79aMfc-SxzE'

triples4 = pd.read_csv(r'auhfI1zWBco-triples.csv')
triples4['key'] = 'auhfI1zWBco'

triples5 = pd.read_csv(r'EWuz7GpeYqQ&t=22s-triples.csv')
triples5['key'] = 'EWuz7GpeYqQ&t=22s'

triples6 = pd.read_csv(r'EWuz7GpeYqQ-triples.csv')
triples6['key'] = 'EWuz7GpeYqQ'

triples7 = pd.read_csv(r'F4VoQelMgTc-triples.csv')
triples7['key'] = 'F4VoQelMgTc'

triples8 = pd.read_csv(r'gohJtZq54rU-triples.csv')
triples8['key'] = 'gohJtZq54rU'

triples9 = pd.read_csv(r'i411gIDzPb4-triples.csv')
triples9['key'] = 'i411gIDzPb4'

triples10 = pd.read_csv(r'JHo9RG0FXwQ-triples.csv')
triples10['key'] = 'JHo9RG0FXwQ'

triples11 = pd.read_csv(r'0JE-VbmzQzo-triples.csv')
triples11['key'] = '0JE-VbmzQzo'

triples12 = pd.read_csv(r'lqd-A6bteqw-triples.csv')
triples12['key'] = 'lqd-A6bteqw'

triples13 = pd.read_csv(r'N4uJIbPb8yU-triples.csv')
triples13['key'] = 'N4uJIbPb8yU'

triples14 = pd.read_csv(r'n8bPLA6jtE0-triples.csv')
triples14['key'] = 'n8bPLA6jtE0'

triples15 = pd.read_csv(r'OQGLZxPcd-o-triples.csv')
triples15['key'] = 'OQGLZxPcd-o'

triples16 = pd.read_csv(r'OvYuAT3J9no-triples.csv')
triples16['key'] = 'OvYuAT3J9no'

triples17 = pd.read_csv(r'R5Xa6eMAriQ-triples.csv')
triples17['key'] = 'R5Xa6eMAriQ'

triples18 = pd.read_csv(r'tD4rVnD9mho-triples.csv')
triples18['key'] = 'tD4rVnD9mho'

triples19 = pd.read_csv(r'XN4GSRObmBA-triples.csv')
triples19['key'] = 'XN4GSRObmBA'

# %%
triples19
# Out:
#     Unnamed: 0             source  \
# 0            0         rev engine
# 1            1         rev engine
# 2            2         rev engine
# 3            3         rev engine
# 4            4           happened
# 5            5           happened
# 6            6        new battery
# 7            7        new battery
# 8            8        new battery
# 9            9            battery
# 10          10        new battery
# 11          11            battery
# 12          12            battery
# 13          13            battery
# 14          14            battery
# 15          15        new battery
# 16          16           computer
# 17          17           computer
# 18          18              power
# 19          19              power
# 20          20  wa working saturn
# 21          21          wa saturn
# 22          22             memory
# 23          23    little research
# 24          24    customer called
# 25          25           customer
# ...

# %%
triples1['triples'] = triples1['source'] + ' ' + triples1['target'] + ' ' + triples1['edge']
triples1

triples2['triples'] = triples2['source'] + ' ' + triples2['target'] + ' ' + triples2['edge']

triples3['triples'] = triples3['source'] + ' ' + triples3['target'] + ' ' + triples3['edge']

triples4['triples'] = triples4['source'] + ' ' + triples4['target'] + ' ' + triples4['edge']

triples5['triples'] = triples5['source'] + ' ' + triples5['target'] + ' ' + triples5['edge']

triples6['triples'] = triples6['source'] + ' ' + triples6['target'] + ' ' + triples6['edge']

triples7['triples'] = triples7['source'] + ' ' + triples7['target'] + ' ' + triples7['edge']

triples8['triples'] = triples8['source'] + ' ' + triples8['target'] + ' ' + triples8['edge']

triples9['triples'] = triples9['source'] + ' ' + triples9['target'] + ' ' + triples9['edge']

triples10['triples'] = triples10['source'] + ' ' + triples10['target'] + ' ' + triples10['edge']

triples11['triples'] = triples11['source'] + ' ' + triples11['target'] + ' ' + triples11['edge']

triples12['triples'] = triples12['source'] + ' ' + triples12['target'] + ' ' + triples12['edge']

triples13['triples'] = triples13['source'] + ' ' + triples13['target'] + ' ' + triples13['edge']

triples14['triples'] = triples14['source'] + ' ' + triples14['target'] + ' ' + triples14['edge']

triples15['triples'] = triples15['source'] + ' ' + triples15['target'] + ' ' + triples15['edge']

triples16['triples'] = triples16['source'] + ' ' + triples16['target'] + ' ' + triples16['edge']

triples17['triples'] = triples17['source'] + ' ' + triples17['target'] + ' ' + triples17['edge']

triples18['triples'] = triples18['source'] + ' ' + triples18['target'] + ' ' + triples18['edge']

triples19['triples'] = triples19['source'] + ' ' + triples19['target'] + ' ' + triples19['edge']

# %%
tokens1 = {'triples': ' '.join(triples1['triples'].tolist())}
tokens1 = pd.DataFrame(tokens1, index=[0])  
tokens1['key'] = '0JE-VbmzQzo'
tokens1

tokens2 = {'triples': ' '.join(triples2['triples'].tolist())}
tokens2 = pd.DataFrame(tokens1, index=[0])  
tokens2['key'] = '1-O7zuaZsAA'

tokens3 = {'triples': ' '.join(triples3['triples'].tolist())}
tokens3 = pd.DataFrame(tokens1, index=[0])  
tokens3['key'] = '79aMfc-SxzE'

tokens4 = {'triples': ' '.join(triples4['triples'].tolist())}
tokens4 = pd.DataFrame(tokens1, index=[0])  
tokens4['key'] = 'auhfI1zWBco'

tokens5 = {'triples': ' '.join(triples5['triples'].tolist())}
tokens5 = pd.DataFrame(tokens1, index=[0])  
tokens5['key'] = 'EWuz7GpeYqQ&t=22s'

tokens6 = {'triples': ' '.join(triples6['triples'].tolist())}
tokens6 = pd.DataFrame(tokens1, index=[0])  
tokens6['key'] = 'EWuz7GpeYqQ'

tokens7 = {'triples': ' '.join(triples7['triples'].tolist())}
tokens7 = pd.DataFrame(tokens1, index=[0])  
tokens7['key'] = 'F4VoQelMgTc'

tokens8 = {'triples': ' '.join(triples8['triples'].tolist())}
tokens8 = pd.DataFrame(tokens1, index=[0])  
tokens8['key'] = 'gohJtZq54rU'

tokens9 = {'triples': ' '.join(triples9['triples'].tolist())}
tokens9 = pd.DataFrame(tokens1, index=[0])  
tokens9['key'] = 'i411gIDzPb4'

tokens10 = {'triples': ' '.join(triples10['triples'].tolist())}
tokens10 = pd.DataFrame(tokens1, index=[0])  
tokens10['key'] = 'JHo9RG0FXwQ'

tokens11 = {'triples': ' '.join(triples11['triples'].tolist())}
tokens11 = pd.DataFrame(tokens1, index=[0])  
tokens11['key'] = '1-O7zuaZsAA'

tokens12 = {'triples': ' '.join(triples12['triples'].tolist())}
tokens12 = pd.DataFrame(tokens1, index=[0])  
tokens12['key'] = 'lqd-A6bteqw'

tokens13 = {'triples': ' '.join(triples13['triples'].tolist())}
tokens13 = pd.DataFrame(tokens1, index=[0])  
tokens13['key'] = 'N4uJIbPb8yU'

tokens14 = {'triples': ' '.join(triples14['triples'].tolist())}
tokens14 = pd.DataFrame(tokens1, index=[0])  
tokens14['key'] = 'n8bPLA6jtE0'

tokens15 = {'triples': ' '.join(triples15['triples'].tolist())}
tokens15 = pd.DataFrame(tokens1, index=[0])  
tokens15['key'] = 'OQGLZxPcd-o'

tokens16 = {'triples': ' '.join(triples16['triples'].tolist())}
tokens16 = pd.DataFrame(tokens1, index=[0])  
tokens16['key'] = 'OvYuAT3J9no'

tokens17 = {'triples': ' '.join(triples17['triples'].tolist())}
tokens17 = pd.DataFrame(tokens1, index=[0])  
tokens17['key'] = 'R5Xa6eMAriQ'

tokens18 = {'triples': ' '.join(triples18['triples'].tolist())}
tokens18 = pd.DataFrame(tokens1, index=[0])  
tokens18['key'] = 'tD4rVnD9mho'

tokens19 = {'triples': ' '.join(triples19['triples'].tolist())}
tokens19 = pd.DataFrame(tokens1, index=[0])  
tokens19['key'] = 'XN4GSRObmBA'

# %%
merge1 = pd.merge(v_df, tokens1,  on= ['key'])
merge2 = pd.merge(v_df, tokens2,  on= ['key'])
merge3 = pd.merge(v_df, tokens3,  on= ['key'])
merge4 = pd.merge(v_df, tokens4,  on= ['key'])
merge5 = pd.merge(v_df, tokens5,  on= ['key'])
merge6 = pd.merge(v_df, tokens6,  on= ['key'])
merge7 = pd.merge(v_df, tokens7,  on= ['key'])
merge8 = pd.merge(v_df, tokens8,  on= ['key'])
merge9 = pd.merge(v_df, tokens9,  on= ['key'])
merge10 = pd.merge(v_df, tokens10,  on= ['key'])
merge11 = pd.merge(v_df, tokens11,  on= ['key'])
merge12 = pd.merge(v_df, tokens12,  on= ['key'])
merge13 = pd.merge(v_df, tokens13,  on= ['key'])
merge14 = pd.merge(v_df, tokens14,  on= ['key'])
merge15 = pd.merge(v_df, tokens15,  on= ['key'])
merge16 = pd.merge(v_df, tokens16,  on= ['key'])
merge17 = pd.merge(v_df, tokens17,  on= ['key'])
merge18 = pd.merge(v_df, tokens18,  on= ['key'])
merge19 = pd.merge(v_df, tokens19,  on= ['key'])

# %%
merge19
# Out:
#    Unnamed: 0                          link  \
# 0          10  https://youtu.be/XN4GSRObmBA
#
#                                           title         author publish_date  \
# 0  How to Replace a Car Battery (the Right Way)  Scotty Kilmer   2018-02-02
#
#     views  length_seconds  rating  Subscribers  Likes  Dislikes  \
# 0  926884             197     NaN      5360000  13000         0
#
#                                           transcript     Reach  Rating  \
# 0  Rev up your engines today, I'm going to show y...  0.172926       1
#
#            key                                            triples
# 0  XN4GSRObmBA  emergency brake key vehicle pop vehicle hood r...
